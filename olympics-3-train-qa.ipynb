# %%
import openai

API_KEY = "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"

# Establece tu clave de API de OpenAI
openai.api_key = API_KEY

# %%
with open('train-v1.1-es.json', 'r') as f:
    datos = json.load(f)

# %%
#datos["data"]

# %%
datos.keys()
# Out:
# dict_keys(['version', 'data'])

# %%
datos["data"][0].keys()
# Out:
# dict_keys(['title', 'paragraphs'])

# %%
datos["data"][0]["paragraphs"][0].keys()
# Out:
# dict_keys(['context', 'qas'])

# %%
datos["data"][0]["paragraphs"][0]["qas"][0].keys()
# Out:
# dict_keys(['question', 'answers', 'id'])

# %%
datos["data"][13]["title"]
# Out:
# 'Energía solar'

# %%
def json_2_df(file_json):
    
    context_list = []
    question_list = []
    answers_dic_list = []
    answers_list = []
    answer_start_list = []
    
    title_list = []
    id_list = []
    
    len_titles = len( datos["data"] )
    
    for j in range( len_titles ):
        
        title = datos["data"][j]["title"]
        
        for dic in datos["data"][j]["paragraphs"]:
            n = len(dic["qas"])

            for i in range(n):
                title_list.append( title )
                
                context_list.append( dic["context"] )
                question_list.append( dic["qas"][i]["question"] )
                id_list.append( dic["qas"][i]["id"] )

                answers_dic_list.append( dic["qas"][i]["answers"][0] )

                answers_list.append( dic["qas"][i]["answers"][0]["text"] )
                answer_start_list.append( dic["qas"][i]["answers"][0]["answer_start"] )

        df = pd.DataFrame( {"id"           : id_list,
                            "title"        : title_list,
                            "context"      : context_list,
                            "questions"     : question_list,
                            "answers_dic"  : answers_dic_list,
                            "answers"      : answers_list,
                            "answer_start" : answer_start_list} )
    
    return df

# %%
train_df = json_2_df('train-v1.1-es.json')
train_df
# Out:
#                              id                            title  \
# 0      5733be284776f41900661182  Universidad _ de _ Notre _ Dame
# 1      5733be284776f4190066117f  Universidad _ de _ Notre _ Dame
# 2      5733be284776f41900661180  Universidad _ de _ Notre _ Dame
# 3      5733be284776f41900661181  Universidad _ de _ Notre _ Dame
# 4      5733be284776f4190066117e  Universidad _ de _ Notre _ Dame
# ...                         ...                              ...
# 87590  5735d259012e2f140011a09d                        Katmandú.
# 87591  5735d259012e2f140011a09e                        Katmandú.
# 87592  5735d259012e2f140011a09f                        Katmandú.
# 87593  5735d259012e2f140011a0a0                        Katmandú.
# 87594  5735d259012e2f140011a0a1                        Katmandú.
#
#                                                  context  \
# 0      Arquitectónicamente, la escuela tiene un carác...
# 1      Arquitectónicamente, la escuela tiene un carác...
# 2      Arquitectónicamente, la escuela tiene un carác...
# 3      Arquitectónicamente, la escuela tiene un carác...
# 4      Arquitectónicamente, la escuela tiene un carác...
# ...                                                  ...
# 87590  La ciudad metropolitana de Katmandú (KMC), con...
# 87591  La ciudad metropolitana de Katmandú (KMC), con...
# 87592  La ciudad metropolitana de Katmandú (KMC), con...
# 87593  La ciudad metropolitana de Katmandú (KMC), con...
# 87594  La ciudad metropolitana de Katmandú (KMC), con...
#
#                                                questions  \
# 0      ¿A quién acudió la Virgen María supuestamente ...
# 1      ¿Qué hay frente al edificio principal de Notre...
# 2      La Basílica del Sagrado Corazón en Notre Dame ...
# 3                        ¿Qué es la Gruta de Notre Dame?
# 4      ¿Qué se encuentra en la parte superior del edi...
# ...                                                  ...
# 87590  ¿En qué estado de EE.UU. estableció por primer...
# 87591                                  ¿Cómo era Rangún?
# 87592  ¿Con qué ciudad bielorrusa tiene una relación ...
# 87593  ¿En qué año creó Katmandú su relación internac...
# 87594                     ¿De qué es KMC un inicialismo?
#
#                                              answers_dic  \
# 0      {'text': 'Santa Bernadette Soubirous', 'answer...
# 1      {'text': 'una estatua de cobre de Cristo', 'an...
# 2      {'text': 'el edificio principal', 'answer_star...
# 3      {'text': 'un lugar mariano de oración y reflex...
# 4      {'text': 'una estatua dorada de la Virgen Marí...
# ...                                                  ...
# 87590            {'text': 'Oregón', 'answer_start': 253}
# 87591           {'text': 'Rangoon', 'answer_start': 447}
# 87592             {'text': 'China', 'answer_start': 502}
# 87593              {'text': '1975', 'answer_start': 223}
# 87594  {'text': 'ciudad metropolitana de Katmandú', '...
#
#                                        answers  answer_start
# 0                   Santa Bernadette Soubirous           572
# 1               una estatua de cobre de Cristo           218
# 2                        el edificio principal            88
# 3      un lugar mariano de oración y reflexión           430
# 4        una estatua dorada de la Virgen María           114
# ...                                        ...           ...
# 87590                                   Oregón           253
# 87591                                  Rangoon           447
# 87592                                    China           502
# 87593                                     1975           223
# 87594         ciudad metropolitana de Katmandú             3
#
# [87595 rows x 7 columns]

# %%
df = train_df[ train_df["title"] == 'Energía solar' ]
df
# Out:
#                             id          title  \
# 4852  56ce55feaab44d1400b886ce  Energía solar
# 4853  56ce55feaab44d1400b886cf  Energía solar
# 4854  56ce9034aab44d1400b8888f  Energía solar
# 4855  56ce9034aab44d1400b88890  Energía solar
# 4856  56ce59c8aab44d1400b886dc  Energía solar
# ...                        ...            ...
# 5097  56d08aa8234ae51400d9c36d  Energía solar
# 5098  56d09354234ae51400d9c3aa  Energía solar
# 5099  56d09354234ae51400d9c3ab  Energía solar
# 5100  56d09a0e234ae51400d9c3c2  Energía solar
# 5101  56d09a0e234ae51400d9c3c3  Energía solar
#
#                                                 context  \
# 4852  La energía solar es la luz radiante y el calor...
# 4853  La energía solar es la luz radiante y el calor...
# 4854  La energía solar es la luz radiante y el calor...
# 4855  La energía solar es la luz radiante y el calor...
# 4856  La Tierra recibe 174.000 terawatts (TW) de rad...
# ...                                                 ...
# 5097  Un globo solar es un globo negro lleno de aire...
# 5098  Comenzando con el aumento del uso del carbón q...
# 5099  Comenzando con el aumento del uso del carbón q...
# 5100  En 2011, un informe de la Agencia Internaciona...
# 5101  En 2011, un informe de la Agencia Internaciona...
#
#                                               questions  \
# 4852               ¿De dónde proviene la energía solar?
# 4853  ¿Qué tipo de energía consiste en la luz y el c...
# 4854  ¿Qué tecnologías se utilizan para aprovechar l...
# 4855                          ¿Qué es la energía solar?
# 4856  ¿Cuántos teravatios de radiación solar recibe ...
# ...                                                 ...
# 5097  ¿Por qué el uso de globos solares se limita tí...
# 5098  ¿Por qué se desarrolló la tecnología solar en ...
# 5099  ¿Qué frenó el desarrollo de las tecnologías so...
# 5100  Según un informe de 2011, ¿para qué año podría...
# 5101  ¿Qué podría hacer la energía del sol para ayud...
#
#                                             answers_dic  \
# 4852             {'text': 'el Sol', 'answer_start': 48}
# 4853       {'text': 'energía solar', 'answer_start': 3}
# 4854  {'text': 'calefacción solar, la energía solar ...
# 4855  {'text': 'luz radiante y el calor del Sol', 'a...
# 4856            {'text': '174.000', 'answer_start': 17}
# ...                                                 ...
# 5097  {'text': 'el área de superficie a la relación ...
# 5098  {'text': 'impulsado por la expectativa de que ...
# 5099  {'text': 'creciente disponibilidad, economía y...
# 5100              {'text': '2060', 'answer_start': 246}
# 5101  {'text': 'podría desempeñar un papel clave en ...
#
#                                                 answers  answer_start
# 4852                                             el Sol            48
# 4853                                      energía solar             3
# 4854  calefacción solar, la energía solar térmica, l...           133
# 4855                    luz radiante y el calor del Sol            23
# 4856                                            174.000            17
# ...                                                 ...           ...
# 5097  el área de superficie a la relación de peso út...           395
# 5098  impulsado por la expectativa de que el carbón ...           261
# 5099  creciente disponibilidad, economía y utilidad ...           429
# 5100                                               2060           246
# 5101  podría desempeñar un papel clave en la descarb...           333
#
# [250 rows x 7 columns]

# %%
df["tokens"] = df.context.apply( lambda x: int( len( x.split() )*(1000/750) ) )
df
# Out:
# C:\Users\josep\AppData\Local\Temp\ipykernel_27184\3968408620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tokens"] = df.context.apply( lambda x: int( len( x.split() )*(1000/750) ) )
#                             id          title  \
# 4852  56ce55feaab44d1400b886ce  Energía solar
# 4853  56ce55feaab44d1400b886cf  Energía solar
# 4854  56ce9034aab44d1400b8888f  Energía solar
# 4855  56ce9034aab44d1400b88890  Energía solar
# 4856  56ce59c8aab44d1400b886dc  Energía solar
# ...                        ...            ...
# 5097  56d08aa8234ae51400d9c36d  Energía solar
# 5098  56d09354234ae51400d9c3aa  Energía solar
# 5099  56d09354234ae51400d9c3ab  Energía solar
# 5100  56d09a0e234ae51400d9c3c2  Energía solar
# 5101  56d09a0e234ae51400d9c3c3  Energía solar
#
#                                                 context  \
# 4852  La energía solar es la luz radiante y el calor...
# 4853  La energía solar es la luz radiante y el calor...
# 4854  La energía solar es la luz radiante y el calor...
# 4855  La energía solar es la luz radiante y el calor...
# 4856  La Tierra recibe 174.000 terawatts (TW) de rad...
# ...                                                 ...
# 5097  Un globo solar es un globo negro lleno de aire...
# 5098  Comenzando con el aumento del uso del carbón q...
# 5099  Comenzando con el aumento del uso del carbón q...
# 5100  En 2011, un informe de la Agencia Internaciona...
# 5101  En 2011, un informe de la Agencia Internaciona...
#
#                                               questions  \
# 4852               ¿De dónde proviene la energía solar?
# 4853  ¿Qué tipo de energía consiste en la luz y el c...
# 4854  ¿Qué tecnologías se utilizan para aprovechar l...
# 4855                          ¿Qué es la energía solar?
# 4856  ¿Cuántos teravatios de radiación solar recibe ...
# ...                                                 ...
# 5097  ¿Por qué el uso de globos solares se limita tí...
# 5098  ¿Por qué se desarrolló la tecnología solar en ...
# 5099  ¿Qué frenó el desarrollo de las tecnologías so...
# 5100  Según un informe de 2011, ¿para qué año podría...
# 5101  ¿Qué podría hacer la energía del sol para ayud...
#
#                                             answers_dic  \
# 4852             {'text': 'el Sol', 'answer_start': 48}
# 4853       {'text': 'energía solar', 'answer_start': 3}
# 4854  {'text': 'calefacción solar, la energía solar ...
# 4855  {'text': 'luz radiante y el calor del Sol', 'a...
# 4856            {'text': '174.000', 'answer_start': 17}
# ...                                                 ...
# 5097  {'text': 'el área de superficie a la relación ...
# 5098  {'text': 'impulsado por la expectativa de que ...
# 5099  {'text': 'creciente disponibilidad, economía y...
# 5100              {'text': '2060', 'answer_start': 246}
# 5101  {'text': 'podría desempeñar un papel clave en ...
#
#                                                 answers  answer_start  tokens
# 4852                                             el Sol            48      48
# 4853                                      energía solar             3      48
# 4854  calefacción solar, la energía solar térmica, l...           133      48
# 4855                    luz radiante y el calor del Sol            23      48
# 4856                                            174.000            17     134
# ...                                                 ...           ...     ...
# 5097  el área de superficie a la relación de peso út...           395     106
# 5098  impulsado por la expectativa de que el carbón ...           261     112
# 5099  creciente disponibilidad, economía y utilidad ...           429     112
# 5100                                               2060           246     138
# 5101  podría desempeñar un papel clave en la descarb...           333     138
#
# [250 rows x 8 columns]

# %%
#df = df[df.tokens<2000]
df[['context', 'tokens']].rename(columns={'context':'text','tokens':'metadata'}).to_json('energia_solar.jsonl', orient='records', lines=True)

search_file = openai.File.create(
  file=open("energia_solar.jsonl"),
  purpose='search'
)
olympics_search_fileid = search_file['id']
olympics_search_fileid  # 'file-Q6Cd6uswkfmLDlzEqY4dZ2uO'
# Out:
# 'file-Q6Cd6uswkfmLDlzEqY4dZ2uO'

# %%
df.to_csv("energia_solar.csv", index = False)

# %% [markdown]
# <span style="color:orange; font-weight:bold">Note: To answer questions based on text documents, we recommend the procedure in <a href="https://github.com/openai/openai-cookbook/blob/main/examples/Question_answering_using_embeddings.ipynb">Question Answering using Embeddings</a>. Some of the code below may rely on <a href="https://github.com/openai/openai-cookbook/tree/main/transition_guides_for_deprecated_API_endpoints">deprecated API endpoints</a>.</span>

# %% [markdown]
# # 3. Train a fine-tuning model specialized for Q&A
# This notebook will utilize the dataset of context, question and answer pairs to additionally create adversarial questions and context pairs, where the question was not generated on that context. In those cases the model will be prompted to answer "No sufficient context for answering the question". We will also train a discriminator model, which predicts whether the question can be answered based on the context or not.
#
# We will add hard adversarial examples as well, which will be based either on semantically similar sections, or neighbouring sections, originating from the same article.

# %%
def json_2_df(file_json):
    
    context_list = []
    question_list = []
    answers_dic_list = []
    answers_list = []
    answer_start_list = []
    
    title_list = []
    id_list = []
    
    len_titles = len( datos["data"] )
    
    for j in range( len_titles ):
        
        title = datos["data"][j]["title"]
        
        for dic in datos["data"][j]["paragraphs"]:
            n = len(dic["qas"])

            for i in range(n):
                title_list.append( title )
                
                context_list.append( dic["context"] )
                question_list.append( dic["qas"][i]["question"] )
                id_list.append( dic["qas"][i]["id"] )

                answers_dic_list.append( dic["qas"][i]["answers"][0] )

                answers_list.append( dic["qas"][i]["answers"][0]["text"] )
                answer_start_list.append( dic["qas"][i]["answers"][0]["answer_start"] )

        df = pd.DataFrame( {"id"           : id_list,
                            "title"        : title_list,
                            "context"      : context_list,
                            "questions"     : question_list,
                            "answers_dic"  : answers_dic_list,
                            "answers"      : answers_list,
                            "answer_start" : answer_start_list} )
    
    return df

# %%
train_df = json_2_df('train-v1.1-es.json')
test_df = json_2_df('dev-v1.1-es.json')

train_df.head()
# Out:
#                                              context  \
# 0  Arquitectónicamente, la escuela tiene un carác...
# 1  Arquitectónicamente, la escuela tiene un carác...
# 2  Arquitectónicamente, la escuela tiene un carác...
# 3  Arquitectónicamente, la escuela tiene un carác...
# 4  Arquitectónicamente, la escuela tiene un carác...
#
#                                             question  \
# 0  ¿A quién acudió la Virgen María supuestamente ...
# 1  ¿Qué hay frente al edificio principal de Notre...
# 2  La Basílica del Sagrado Corazón en Notre Dame ...
# 3                    ¿Qué es la Gruta de Notre Dame?
# 4  ¿Qué se encuentra en la parte superior del edi...
#
#                                              answers  \
# 0  {'text': 'Santa Bernadette Soubirous', 'answer...
# 1  {'text': 'una estatua de cobre de Cristo', 'an...
# 2  {'text': 'el edificio principal', 'answer_star...
# 3  {'text': 'un lugar mariano de oración y reflex...
# 4  {'text': 'una estatua dorada de la Virgen Marí...
#
#                                     answer  answer_start
# 0               Santa Bernadette Soubirous           572
# 1           una estatua de cobre de Cristo           218
# 2                    el edificio principal            88
# 3  un lugar mariano de oración y reflexión           430
# 4    una estatua dorada de la Virgen María           114

# %%
train_df.columns = ['context', 'questions', 'answers_dic', 'answers', 'answer_start']
test_df.columns = ['context', 'questions', 'answers_dic', 'answers', 'answer_start']

# %%
test_df.head()
# Out:
#                                              context  \
# 0  El Super Bowl 50 fue un partido de fútbol amer...
# 1  El Super Bowl 50 fue un partido de fútbol amer...
# 2  El Super Bowl 50 fue un partido de fútbol amer...
# 3  El Super Bowl 50 fue un partido de fútbol amer...
# 4  El Super Bowl 50 fue un partido de fútbol amer...
#
#                                            questions  \
# 0  ¿Qué equipo de la NFL representó a la AFC en e...
# 1  ¿Qué equipo de la NFL representó a la NFC en e...
# 2                ¿Dónde tuvo lugar el Super Bowl 50?
# 3       ¿Qué equipo de la NFL ganó el Super Bowl 50?
# 4  ¿De qué color se utilizó para enfatizar el 50 ...
#
#                                          answers_dic                  answers  \
# 0    {'text': 'Denver Broncos', 'answer_start': 165}           Denver Broncos
# 1  {'text': 'Carolina Panthers', 'answer_start': ...        Carolina Panthers
# 2  {'text': 'Santa Clara, California', 'answer_st...  Santa Clara, California
# 3    {'text': 'Denver Broncos', 'answer_start': 165}           Denver Broncos
# 4               {'text': 'oro', 'answer_start': 539}                      oro
#
#    answer_start
# 0           165
# 1           240
# 2           404
# 3           165
# 4           539

# %%
train_df.context.str.contains('->').sum()
# Out:
# 0

# %%
train_df.title.value_counts()
# Out:
# Música                                             538
# Universidad                                        538
# Disolución _ de _ el _ Unión _ soviética           269
# Estrasburgo                                        269
# Exposición _ juego                                 269
#                                                   ...
# Military _ history _ of _ the _ United _ States    269
# Xbox _ 360                                         269
# Calendario gregoriano                              269
# Videoconferencia                                   269
# Katmandú.                                          269
# Name: title, Length: 440, dtype: int64

# %%
train_df[ train_df["title"] == "Música"  ]
# Out:
#                              id   title  \
# 22327  5733be284776f41900661182  Música
# 22328  5733be284776f4190066117f  Música
# 22329  5733be284776f41900661180  Música
# 22330  5733be284776f41900661181  Música
# 22331  5733be284776f4190066117e  Música
# ...                         ...     ...
# 30661  5733cd504776f4190066128e  Música
# 30662  5733cd504776f4190066128f  Música
# 30663  5733cd504776f41900661290  Música
# 30664  5733cd504776f41900661291  Música
# 30665  5733cd504776f41900661292  Música
#
#                                                  context  \
# 22327  Arquitectónicamente, la escuela tiene un carác...
# 22328  Arquitectónicamente, la escuela tiene un carác...
# 22329  Arquitectónicamente, la escuela tiene un carác...
# 22330  Arquitectónicamente, la escuela tiene un carác...
# 22331  Arquitectónicamente, la escuela tiene un carác...
# ...                                                  ...
# 30661  Los alumnos de Notre Dame trabajan en varios c...
# 30662  Los alumnos de Notre Dame trabajan en varios c...
# 30663  Los alumnos de Notre Dame trabajan en varios c...
# 30664  Los alumnos de Notre Dame trabajan en varios c...
# 30665  Los alumnos de Notre Dame trabajan en varios c...
#
#                                                 question  \
# 22327  ¿A quién acudió la Virgen María supuestamente ...
# 22328  ¿Qué hay frente al edificio principal de Notre...
# 22329  La Basílica del Sagrado Corazón en Notre Dame ...
# 22330                    ¿Qué es la Gruta de Notre Dame?
# 22331  ¿Qué se encuentra en la parte superior del edi...
# ...                                                  ...
# 30661    ¿Qué Secretario de Estado asistió a Notre Dame?
# 30662  ¿Cuál alumbre de Notre Dame del Colegio de Cie...
# 30663      ¿Quién es el actual presidente de Notre Dame?
# 30664          Mariel Zagunis es notable por ganar ¿qué?
# 30665  ¿Qué astronauta notable ha asistido a Notre Dame?
#
#                                              answers_dic  \
# 22327  {'text': 'Santa Bernadette Soubirous', 'answer...
# 22328  {'text': 'una estatua de cobre de Cristo', 'an...
# 22329  {'text': 'el edificio principal', 'answer_star...
# 22330  {'text': 'un lugar mariano de oración y reflex...
# 22331  {'text': 'una estatua dorada de la Virgen Marí...
# ...                                                  ...
# 30661  {'text': 'Condoleezza Rice', 'answer_start': 229}
# 30662  {'text': 'Eric F. Wieschaus', 'answer_start': ...
# 30663      {'text': 'John Jenkins', 'answer_start': 451}
# 30664               {'text': 'Joe', 'answer_start': 898}
# 30665     {'text': 'astronauta Ji', 'answer_start': 998}
#
#                                        answers  answer_start
# 22327               Santa Bernadette Soubirous           572
# 22328           una estatua de cobre de Cristo           218
# 22329                    el edificio principal            88
# 22330  un lugar mariano de oración y reflexión           430
# 22331    una estatua dorada de la Virgen María           114
# ...                                        ...           ...
# 30661                         Condoleezza Rice           229
# 30662                        Eric F. Wieschaus           335
# 30663                             John Jenkins           451
# 30664                                      Joe           898
# 30665                            astronauta Ji           998
#
# [538 rows x 7 columns]

# %%
import openai
import pandas as pd
df = pd.read_csv("olympics-data/olympics_qa.csv")           # "olympics-data/olympics_qa.csv"   //   'energia_solar.csv'
olympics_search_fileid = 'file-Q6Cd6uswkfmLDlzEqY4dZ2uO'    # OLYMPICS : 'file-vz8dowX2rwzgBtZE0ntaI3ka'
                                                            # EN_SOLAR : 'file-Q6Cd6uswkfmLDlzEqY4dZ2uO'
df.head()
# Out:
#                                        title                      heading  \
# 0  United States at the 2020 Summer Olympics                      Summary
# 1  United States at the 2020 Summer Olympics                    Medalists
# 2  United States at the 2020 Summer Olympics                      Archery
# 3  United States at the 2020 Summer Olympics            Artistic swimming
# 4  United States at the 2020 Summer Olympics  Athletics (track and field)
#
#                                              content  tokens  \
# 0  The United States, represented by the United S...     310
# 1  The following U.S. competitors won medals at t...      44
# 2  One U.S. archer qualified for the men's indivi...     145
# 3  The United States fielded a squad of two artis...      41
# 4  U.S. athletes achieved the entry standards, ei...     559
#
#                                              context  \
# 0  United States at the 2020 Summer Olympics\nSum...
# 1  United States at the 2020 Summer Olympics\nMed...
# 2  United States at the 2020 Summer Olympics\nArc...
# 3  United States at the 2020 Summer Olympics\nArt...
# 4  United States at the 2020 Summer Olympics\nAth...
#
#                                            questions  \
# 0  1. What is the name of the United States Olymp...
# 1  1. What is the name of the person who won a go...
# 2  1. How many U.S. archers qualified for the 202...
# 3  1. What is the name of the event?\n2. What is ...
# 4  1. What is the name of the event in which the ...
#
#                                              answers
# 0  1. The United States Olympic Committee is the ...
# 1                                       1. \n2. \n3.
# 2  1. One U.S. archer qualified for the 2020 Olym...
# 3  1. The event is called the women's duet.\n2. T...
# 4  1. Track and field events\n2. Track and field ...

# %% [markdown]
# Split the sections into a training and testing set

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
len(train_df), len(test_df)
# Out:
# (35, 9)

# %% [markdown]
# we check that he separator we intend to use isn't present within the contexts

# %%
df.context.str.contains('->').sum()
# Out:
# 0

# %% [markdown]
# ## 3.1 Create the fine-tuning datasets for Q&A and discriminator models
# The fine-tuning dataset is created in the following way. For every corresponding question, answer and context pair we create:
# - Positive example: correct question, answer, context pair
# - Negative examples:
#   - random negative example, where the random context is paired with the question
#   - two hard negative examples
#     - one originating from the same wikipedia article
#     - another, which is most similar to the correct context
#
# This process is noisy, as sometimes the question might be answerable given a different context, but on average we hope this won't affect the peformance too much.
#
# We apply the same process of dataset creation for both the discriminator, and the Q&A answering model. We apply the process separately for the training and testing set, to ensure that the examples from the traing set don't feature within the test set.

# %%
import openai

openai.api_key = API_KEY

models = openai.Model.list()

for model in models['data']:
    print(model.id)

# %%
openai.Engine().search()

# %%
import random

def get_random_similar_contexts(question, context, file_id=olympics_search_fileid, search_model='ada-search-document', max_rerank=10):
    """
    Find similar contexts to the given context using the search file
    """
    #try:
    results = openai.Engine(search_model).search(
        search_model=search_model, 
        query=question, 
        max_rerank=max_rerank,
        file=file_id
    )
    candidates = []
    for result in results['data'][:3]:
        if result['text'] == context:
            continue
        candidates.append(result['text'])
    random_candidate = random.choice(candidates)
    return random_candidate
    #except Exception as e:
    #    print(e)
    #    return ""
    
def create_fine_tuning_dataset(df, discriminator=False, n_negative=1, add_related=False):
    """
    Create a dataset for fine tuning the OpenAI model; either for a discriminator model, 
    or a model specializing in Q&A, where it says if no relevant context is found.

    Parameters
    ----------
    df: pd.DataFrame
        The dataframe containing the question, answer and context pairs
    discriminator: bool
        Whether to create a dataset for the discriminator
    n_negative: int
        The number of random negative samples to add (using a random context)
    add_related: bool
        Whether to add the related contexts to the correct context. These are hard negative examples

    Returns
    -------
    pd.DataFrame
        The dataframe containing the prompts and completions, ready for fine-tuning
    """
    rows = []
    for i, row in df.iterrows():
        for q, a in zip(("1." + row.questions).split('\n'), ("1." + row.answers).split('\n')):
            if len(q) >10 and len(a) >10:
                if discriminator:
                    rows.append({"prompt":f"{row.context}\nQuestion: {q[2:].strip()}\n Related:", "completion":f" yes"})
                else:
                    rows.append({"prompt":f"{row.context}\nQuestion: {q[2:].strip()}\nAnswer:", "completion":f" {a[2:].strip()}"})

    for i, row in df.iterrows():
        for q in ("1." + row.questions).split('\n'):
            if len(q) >10:
                for j in range(n_negative + (2 if add_related else 0)):
                    random_context = ""
                    if j == 0 and add_related:
                        # add the related contexts based on originating from the same wikipedia page
                        subset = df[(df.title == row.title) & (df.context != row.context)]
                        
                        if len(subset) < 1:
                            continue
                        random_context = subset.sample(1).iloc[0].context
                    if j == 1 and add_related:
                        # add the related contexts based on the most similar contexts according to the search
                        random_context = get_random_similar_contexts(q[2:].strip(), row.context, search_model='ada-search-document', max_rerank=10)
                    else:
                        while True:
                            # add random context, which isn't the correct context
                            random_context = df.sample(1).iloc[0].context
                            if random_context != row.context:
                                break
                    if discriminator:
                        rows.append({"prompt":f"{random_context}\nQuestion: {q[2:].strip()}\n Related:", "completion":f" no"})
                    else:
                        rows.append({"prompt":f"{random_context}\nQuestion: {q[2:].strip()}\nAnswer:", "completion":f" No appropriate context found to answer the question."})

    return pd.DataFrame(rows)

# %% [markdown]
# We apply the same process of dataset creation for both the discriminator, and the Q&A answering model. We apply the process separately for the training and testing set, to ensure that the examples from the traing set don't feature within the test set.

# %%
for name, is_disc in [('discriminator', True), ('qa', False)]:
    for train_test, dt in [('train', train_df), ('test', test_df)]:
        ft = create_fine_tuning_dataset(dt, discriminator=is_disc, n_negative=1, add_related=True)
        ft.to_json(f'{name}_{train_test}.jsonl', orient='records', lines=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In [107], line 3
#       1 for name, is_disc in [('discriminator', True), ('qa', False)]:
#       2     for train_test, dt in [('train', train_df), ('test', test_df)]:
# ----> 3         ft = create_fine_tuning_dataset(dt, discriminator=is_disc, n_negative=1, add_related=True)
#       4         ft.to_json(f'{name}_{train_test}.jsonl', orient='records', lines=True)
#
# Cell In [106], line 69, in create_fine_tuning_dataset(df, discriminator, n_negative, add_related)
#      66     random_context = subset.sample(1).iloc[0].context
#      67 if j == 1 and add_related:
#      68     # add the related contexts based on the most similar contexts according to the search
# ---> 69     random_context = get_random_similar_contexts(q[2:].strip(), row.context, search_model='ada-search-document', max_rerank=10)
#      70 else:
#      71     while True:
#      72         # add random context, which isn't the correct context
#
# Cell In [106], line 8, in get_random_similar_contexts(question, context, file_id, search_model, max_rerank)
#       4 """
#       5 Find similar contexts to the given context using the search file
#       6 """
#       7 #try:
# ----> 8 results = openai.Engine(search_model).search(
#       9     search_model=search_model,
#      10     query=question,
#      11     max_rerank=max_rerank,
#      12     file=file_id
#      13 )
#      14 candidates = []
#      15 for result in results['data'][:3]:
#
# File ~\anaconda3\envs\nlp-39\lib\site-packages\openai\api_resources\engine.py:34, in Engine.search(self, **params)
#      32     return self.request("post", self.instance_url("search"), params)
#      33 elif self.typed_api_type == ApiType.OPEN_AI:
# ---> 34     return self.request("post", self.instance_url() + "/search", params)
#      35 else:
#      36     raise InvalidAPIType("Unsupported API type %s" % self.api_type)
#
# File ~\anaconda3\envs\nlp-39\lib\site-packages\openai\openai_object.py:179, in OpenAIObject.request(self, method, url, params, headers, stream, plain_old_data, request_id, request_timeout)
#     171     params = self._retrieve_params
#     172 requestor = api_requestor.APIRequestor(
#     173     key=self.api_key,
#     174     api_base=self.api_base_override or self.api_base(),
#    (...)
#     177     organization=self.organization,
#     178 )
# --> 179 response, stream, api_key = requestor.request(
#     180     method,
#     181     url,
#     182     params=params,
#     183     stream=stream,
#     184     headers=headers,
#     185     request_id=request_id,
#     186     request_timeout=request_timeout,
#     187 )
#     189 if stream:
#     190     assert not isinstance(response, OpenAIResponse)  # must be an iterator
#
# File ~\anaconda3\envs\nlp-39\lib\site-packages\openai\api_requestor.py:181, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     160 def request(
#     161     self,
#     162     method,
#    (...)
#     169     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     170 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     171     result = self.request_raw(
#     172         method.lower(),
#     173         url,
#    (...)
#     179         request_timeout=request_timeout,
#     180     )
# --> 181     resp, got_stream = self._interpret_response(result, stream)
#     182     return resp, got_stream, self.api_key
#
# File ~\anaconda3\envs\nlp-39\lib\site-packages\openai\api_requestor.py:396, in APIRequestor._interpret_response(self, result, stream)
#     388     return (
#     389         self._interpret_response_line(
#     390             line, result.status_code, result.headers, stream=True
#     391         )
#     392         for line in parse_stream(result.iter_lines())
#     393     ), True
#     394 else:
#     395     return (
# --> 396         self._interpret_response_line(
#     397             result.content, result.status_code, result.headers, stream=False
#     398         ),
#     399         False,
#     400     )
#
# File ~\anaconda3\envs\nlp-39\lib\site-packages\openai\api_requestor.py:429, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     427 stream_error = stream and "error" in resp.data
#     428 if stream_error or not 200 <= rcode < 300:
# --> 429     raise self.handle_error_response(
#     430         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     431     )
#     432 return resp
#
# InvalidRequestError: Invalid URL (POST /v1/engines/ada-search-document/search)

# %% [markdown]
# We formatted the data according to the recommendations from the fine-tuning tool, which is available using
# > openai tools fine_tunes.prepare_data -f qa_train.jsonl
#
# We highly recommend that you use this tool, which suggests improvements in your data formatting for fine-tuning.

# %%
df
# Out:
#                                         title                      heading  \
# 0   United States at the 2020 Summer Olympics                      Summary
# 1   United States at the 2020 Summer Olympics                    Medalists
# 2   United States at the 2020 Summer Olympics                      Archery
# 3   United States at the 2020 Summer Olympics            Artistic swimming
# 4   United States at the 2020 Summer Olympics  Athletics (track and field)
# 5   United States at the 2020 Summer Olympics                    Badminton
# 6   United States at the 2020 Summer Olympics                     Baseball
# 7   United States at the 2020 Summer Olympics                   Basketball
# 8   United States at the 2020 Summer Olympics             Men's tournament
# 9   United States at the 2020 Summer Olympics           Women's tournament
# 10  United States at the 2020 Summer Olympics               3×3 basketball
# 11  United States at the 2020 Summer Olympics                       Boxing
# 12  United States at the 2020 Summer Olympics                       Slalom
# 13  United States at the 2020 Summer Olympics                       Sprint
# 14  United States at the 2020 Summer Olympics                      Cycling
# 15  United States at the 2020 Summer Olympics                         Road
# 16  United States at the 2020 Summer Olympics                        Track
# 17  United States at the 2020 Summer Olympics              Mountain biking
# 18  United States at the 2020 Summer Olympics                          BMX
# 19  United States at the 2020 Summer Olympics                       Diving
# 20  United States at the 2020 Summer Olympics                   Equestrian
# 21  United States at the 2020 Summer Olympics                     Dressage
# 22  United States at the 2020 Summer Olympics                     Eventing
# 23  United States at the 2020 Summer Olympics                      Jumping
# 24  United States at the 2020 Summer Olympics                      Fencing
# 25  United States at the 2020 Summer Olympics                         Golf
# 26  United States at the 2020 Summer Olympics                     Artistic
# 27  United States at the 2020 Summer Olympics                     Rhythmic
# 28  United States at the 2020 Summer Olympics                       Karate
# 29  United States at the 2020 Summer Olympics            Modern pentathlon
# 30  United States at the 2020 Summer Olympics                       Rowing
# 31  United States at the 2020 Summer Olympics                      Sailing
# 32  United States at the 2020 Summer Olympics                     Shooting
# 33  United States at the 2020 Summer Olympics                Skateboarding
# 34  United States at the 2020 Summer Olympics                     Softball
# 35  United States at the 2020 Summer Olympics               Sport climbing
# 36  United States at the 2020 Summer Olympics                      Surfing
# 37  United States at the 2020 Summer Olympics                     Swimming
# 38  United States at the 2020 Summer Olympics                 Table tennis
# 39  United States at the 2020 Summer Olympics                    Taekwondo
# 40  United States at the 2020 Summer Olympics                       Tennis
# 41  United States at the 2020 Summer Olympics                   Volleyball
# 42  United States at the 2020 Summer Olympics                Weightlifting
# 43  United States at the 2020 Summer Olympics                    Wrestling
#
#                                               content  tokens  \
# 0   The United States, represented by the United S...     310
# 1   The following U.S. competitors won medals at t...      44
# 2   One U.S. archer qualified for the men's indivi...     145
# 3   The United States fielded a squad of two artis...      41
# 4   U.S. athletes achieved the entry standards, ei...     559
# 5   The United States entered four badminton playe...     122
# 6   The U.S. baseball team qualified for the Olymp...      51
# 7   The United States men's basketball team won th...      50
# 8   The U.S. men's basketball team qualified for t...      74
# 9   The U.S. women's basketball team qualified for...      66
# 10  In 3x3 men's basketball, the 2019 world champi...      41
# 11  The United States entered ten boxers into the ...      51
# 12  U.S. canoeists qualified one boat for each of ...     101
# 13  The United States qualified a single boat in t...     110
# 14  The Americans won a bronze medal in women's tr...     122
# 15  Six U.S. riders (two men and four women) enter...      99
# 16  Following the completion of the 2020 UCI Track...      78
# 17  The United States entered three mountain biker...      49
# 18  U.S. riders qualified for five quota place (tw...     116
# 19  U.S. divers qualified for the following indivi...      88
# 20  U.S. equestrians qualified a full squad each i...      54
# 21  The U.S. Olympic dressage team was announced o...     101
# 22  The U.S. Olympic eventing team was announced o...     109
# 23  The U.S. Olympic jumping team was named on Jul...      44
# 24  U.S. fencers qualified a full squad each in th...     413
# 25  The United States entered a total of four male...     145
# 26  The United States fielded a full squad of eigh...     269
# 27  Two U.S rhythmic gymnasts qualified for the in...      88
# 28  Four U.S. karateka were entered into the inaug...     100
# 29  U.S. athletes qualified for the following spot...      80
# 30  The United States qualified the nine boats in ...     386
# 31  U.S. sailors qualified one boat in each of the...     353
# 32  U.S. shooters achieved quota places for the fo...     200
# 33  The United States qualified seven skateboarder...      84
# 34  The U.S. women's softball team qualified for t...     113
# 35  U.S. athletes qualified for the following spot...     159
# 36  U.S. surfers qualified for the following spots...     117
# 37  U.S. swimmers achieved qualifying standards in...     327
# 38  Six U.S. athletes were entered into the table ...     149
# 39  Two U.S. athletes were entered into the taekwo...     184
# 40  The United States entered eight tennis players...     376
# 41  In volleyball, the U.S. men's team did not adv...     127
# 42  U.S. weightlifters qualified for eight quota p...      51
# 43  The United States qualified fifteen wrestlers ...     589
#
#                                               context  \
# 0   United States at the 2020 Summer Olympics\nSum...
# 1   United States at the 2020 Summer Olympics\nMed...
# 2   United States at the 2020 Summer Olympics\nArc...
# 3   United States at the 2020 Summer Olympics\nArt...
# 4   United States at the 2020 Summer Olympics\nAth...
# 5   United States at the 2020 Summer Olympics\nBad...
# 6   United States at the 2020 Summer Olympics\nBas...
# 7   United States at the 2020 Summer Olympics\nBas...
# 8   United States at the 2020 Summer Olympics\nMen...
# 9   United States at the 2020 Summer Olympics\nWom...
# 10  United States at the 2020 Summer Olympics\n3×3...
# 11  United States at the 2020 Summer Olympics\nBox...
# 12  United States at the 2020 Summer Olympics\nSla...
# 13  United States at the 2020 Summer Olympics\nSpr...
# 14  United States at the 2020 Summer Olympics\nCyc...
# 15  United States at the 2020 Summer Olympics\nRoa...
# 16  United States at the 2020 Summer Olympics\nTra...
# 17  United States at the 2020 Summer Olympics\nMou...
# 18  United States at the 2020 Summer Olympics\nBMX...
# 19  United States at the 2020 Summer Olympics\nDiv...
# 20  United States at the 2020 Summer Olympics\nEqu...
# 21  United States at the 2020 Summer Olympics\nDre...
# 22  United States at the 2020 Summer Olympics\nEve...
# 23  United States at the 2020 Summer Olympics\nJum...
# 24  United States at the 2020 Summer Olympics\nFen...
# 25  United States at the 2020 Summer Olympics\nGol...
# 26  United States at the 2020 Summer Olympics\nArt...
# 27  United States at the 2020 Summer Olympics\nRhy...
# 28  United States at the 2020 Summer Olympics\nKar...
# 29  United States at the 2020 Summer Olympics\nMod...
# 30  United States at the 2020 Summer Olympics\nRow...
# 31  United States at the 2020 Summer Olympics\nSai...
# 32  United States at the 2020 Summer Olympics\nSho...
# 33  United States at the 2020 Summer Olympics\nSka...
# 34  United States at the 2020 Summer Olympics\nSof...
# 35  United States at the 2020 Summer Olympics\nSpo...
# 36  United States at the 2020 Summer Olympics\nSur...
# 37  United States at the 2020 Summer Olympics\nSwi...
# 38  United States at the 2020 Summer Olympics\nTab...
# 39  United States at the 2020 Summer Olympics\nTae...
# 40  United States at the 2020 Summer Olympics\nTen...
# 41  United States at the 2020 Summer Olympics\nVol...
# 42  United States at the 2020 Summer Olympics\nWei...
# 43  United States at the 2020 Summer Olympics\nWre...
#
#                                             questions  \
# 0   1. What is the name of the United States Olymp...
# 1   1. What is the name of the person who won a go...
# 2   1. How many U.S. archers qualified for the 202...
# 3   1. What is the name of the event?\n2. What is ...
# 4   1. What is the name of the event in which the ...
# 5   1. What is the name of the sport?\n2. What is ...
# 6   1. What is the name of the event?\n2. What is ...
# 7   1. What is the name of the United States men's...
# 8   1. What is the name of the team?\n2. What is t...
# 9   1. What is the name of the team?\n2. What is t...
# 10  1. What is 3x3 basketball?\n2. What is the U.S...
# 11  1. What is the name of the event?\n2. How many...
# 12  1. What is the name of the boat that the U.S. ...
# 13  1. What is the name of the boat that the Unite...
# 14  1. What is the name of the event that the Amer...
# 15  1. What is the name of the event?\n2. What is ...
# 16  1. What are the events that U.S. riders have q...
# 17  1. What is the name of the event?\n2. What is ...
# 18  1. What is BMX?\n2. What is the UCI BMX Olympi...
# 19  1. How many individual spots did the U.S. dive...
# 20  1. What is the name of the event in which the ...
# 21  1. What is the name of the team leader?\n2. Wh...
# 22  1. What is the name of the eventing team?\n2. ...
# 23  1. What is the name of the Olympic team?\n2. W...
# 24  1. What is the name of the event?\n2. What is ...
# 25  1. How many golfers did the United States ente...
# 26  1. What is the name of the gymnast who won the...
# 27  1. What is the name of the sport?\n2. What is ...
# 28  1. What is the name of the sport?\n2. What is ...
# 29  1. What is the name of the sport?\n2. What is ...
# 30  1. What is the name of the boat that the Unite...
# 31  1. What is the name of the boat that the U.S. ...
# 32  1. What is the name of the event?\n2. What is ...
# 33  1. How many skateboarders qualified for the 20...
# 34  1. What is the name of the sport?\n2. What is ...
# 35  1. What is the name of the sport?\n2. What is ...
# 36  1. What is the name of the sport?\n2. What is ...
# 37  1. What is the name of the event in which the ...
# 38  1. What is the name of the event?\n2. What is ...
# 39  1. What is the name of the sport?\n2. What is ...
# 40  1. What is the name of the top ranked American...
# 41  1. What is the name of the virus that Taylor C...
# 42  1. How many quota places did the U.S. qualify ...
# 43  1. What is the name of the event?\n2. What is ...
#
#                                               answers
# 0   1. The United States Olympic Committee is the ...
# 1                                        1. \n2. \n3.
# 2   1. One U.S. archer qualified for the 2020 Olym...
# 3   1. The event is called the women's duet.\n2. T...
# 4   1. Track and field events\n2. Track and field ...
# 5   1. The sport is badminton.\n2. Beiwen Zhang wa...
# 6   1. The event is the Olympics.\n2. The team is ...
# 7   1. The United States men's basketball team.\n2...
# 8   1. The name of the team is the United States m...
# 9   1. The U.S. women's basketball team.\n2. The 2...
# 10  1. 3x3 basketball is a variation of basketball...
# 11  1. The event is boxing.\n2. The United States ...
# 12  1. The boat that the U.S. qualified for the 20...
# 13  1. The United States qualified a single boat i...
# 14  1. The Americans won a bronze medal in women's...
# 15  1. The event is the 2020 Summer Olympics.\n2. ...
# 16  1. U.S. riders have qualified for the sprint, ...
# 17  1. The event is the women's Olympic cross-coun...
# 18  1. BMX is a type of racing.\n2. The UCI BMX Ol...
# 19  1. The U.S. divers qualified for three individ...
# 20  1. The event in which the U.S. qualified a ful...
# 21  1. Adrienne Lyle is the team leader.\n2. Steff...
# 22  1. The name of the eventing team is the U.S. O...
# 23  1. The Olympic team is the U.S. Olympic jumpin...
# 24  1. The event is fencing.\n2. Gerek Meinhardt.\...
# 25  1. The United States entered a total of four m...
# 26   1. Sunisa Lee\n2. Jordan Chiles\n3. Simone Biles
# 27  1. Rhythmic\n2. Individual\n3. Group\n4. Indiv...
# 28      1. Karate\n2. Sakura Kokumai\n3. Thomas Scott
# 29  1. The sport is called modern pentathlon.\n2. ...
# 30  1. The United States qualified the most boats ...
# 31  1. The U.S. sailors qualified one boat in each...
# 32            1. Shooting\n2. Men\n3. Women\n4. Mixed
# 33  1. The United States qualified seven skateboar...
# 34  1. The sport is softball.\n2. The team is the ...
# 35  1. The name of the sport is sport climbing.\n2...
# 36  1. Surfing\n2. Kolohe Andino\n3. John John Flo...
# 37  1. Swimming\n2. 100m breaststroke\n3. 100m bac...
# 38  1. The event is table tennis.\n2. The Olympic ...
# 39  1. The sport is Taekwondo.\n2. Paige McPherson...
# 40  1. Reilly Opelka\n2. Serena Williams\n3. Tommy...
# 41  1. COVID-19\n2. U.S. men's volleyball team\n3....
# 42  1. The U.S. qualified for eight quota places.\...
# 43  1. Wrestling\n2. Kyle Snyder\n3. Abdulrashid S...

# %%
# !openai api fine_tunes.create -t "olympics-data/olympics_qa.csv"
# Out:
# Error: No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://onboard.openai.com for details, or email support@openai.com if you have any questions.

# %% [markdown]
# ## 3.2 Submit the datasets for fine-tuning

# %%
# !openai api fine_tunes.create -t "olympics-data/discriminator_train.jsonl" -v "olympics-data/discriminator_test.jsonl" --batch_size 16  --compute_classification_metrics --classification_positive_class " yes" --model ada

# %%
# !openai api fine_tunes.create -t "olympics-data/qa_train.jsonl" -v "olympics-data/qa_test.jsonl" --batch_size 16

# %% [markdown]
# ## 3.3 Using the fine-tuned models
#
# We will now use the fine-tuned discriminator and the fine-tuned Q&A model. By requesting logprobs, we can see how certain the discriminator is in a `yes` vs `no` answer.

# %%
ft_discriminator = "curie:ft-openai-internal-2021-08-23-23-58-57"
ft_qa = "curie:ft-openai-internal-2021-08-23-17-54-10"

def apply_ft_discriminator(context, question, discriminator_model):
    """
    Apply the fine tuned discriminator to a question, to assess whether it can be answered from the context.
    """
    prompt = f"{context}\nQuestion: {question}\n Related:"
    result = openai.Completion.create(model=discriminator_model, prompt=prompt, max_tokens=1, temperature=0, top_p=1, n=1, logprobs=2)
    return result['choices'][0]['logprobs']['top_logprobs']

apply_ft_discriminator('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.', 
                        'What was the first human-made object in space?', ft_discriminator)
# Out:
# [<OpenAIObject at 0x7fe812e602b0> JSON: {
#    " no": -10.819577,
#    " yes": -2.045765e-05
#  }]

# %% [markdown]
# We can see that the model can generalize well to different contexts and questions.

# %%
def apply_ft_qa_answer(context, question, answering_model):
    """
    Apply the fine tuned discriminator to a question
    """
    prompt = f"{context}\nQuestion: {question}\nAnswer:"
    result = openai.Completion.create(model=answering_model, prompt=prompt, max_tokens=30, temperature=0, top_p=1, n=1, stop=['.','\n'])
    return result['choices'][0]['text']

apply_ft_qa_answer('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.', 
                    'What was the first human-made object in space?', ft_qa)
# Out:
# ' The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957'

# %% [markdown]
# We can see that the model can answer the question, when the context is appropriate.

# %%
apply_ft_qa_answer('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.',
                    'What is impressive about the Soviet Union?', ft_qa)
# Out:
# ' The Soviet Union was the first country to successfully launch a satellite into space'

# %%
apply_ft_qa_answer('The first human-made object in space was the Soviet Union satellite Sputnik 1 on 4 October 1957.',
                    'How many cars were produced in the Soviet Union in 1970?', ft_qa)
# Out:
# ' No appropriate context found to answer the question'

# %% [markdown]
# We can see that the model knows when to answer the question, and when to say that insufficient context is present to answer the question.

# %% [markdown]
# We can also combine a discriminator and a base model, or a fine-tuned Q&A model. Discriminator can essentially serve as a decision whether the question can be answered given the context or not.

# %%
def answer_question_conditionally(answering_model, discriminator_model, context, question, discriminator_logprob_yes_modifier=0):
    logprobs = apply_ft_discriminator(context, question, discriminator_model)
    yes_logprob = logprobs[' yes'] if ' yes' in logprobs else -100
    no_logprob = logprobs[' no'] if ' no' in logprobs else -100
    if yes_logprob + discriminator_logprob_yes_modifier < no_logprob:
        return " No appropriate context found to answer the question based on the discriminator."
    return apply_ft_qa_answer(context, question, answering_model)
answer_question_conditionally(ft_qa, ft_discriminator, 
                                "Crowdless games are a rare although not unheard-of occurrence in sports. \
                                 When they do occur, it is usually the result of events beyond the control \
                                 of the teams or fans, such as weather-related concerns, public health concerns, \
                                 or wider civil disturbances unrelated to the game. For instance, \
                                 the COVID-19 pandemic caused many sports leagues around the world \
                                 to be played behind closed doors.",
                                "Could weather cause a sport event to have no crowd?")
# Out:
# ' Weather could cause a sport event to have no crowd'

# %% [markdown]
# The above function illustrates how to potentially combine a discriminator and a fine-tuned Q&A model. This gives a more fine-grained control over how certain we want the model to be before it answers the question.
#
# We'll now take a look on how answers endpoint works - combining search to retrieve the relevant context from a knowledge base, and then using the fine-tuned Q&A model to answer the question.

# %% [markdown]
# ## 3.4 Answering the question based on a knowledge base
# Finally we can use a logic similar to the [/answers](https://beta.openai.com/docs/api-reference/answers) endpoint, where we first search for the relevant context, and then ask a Q&A model to answer the question given that context. If you'd like to see the implementation details, check out the [`answers_with_ft.py`](answers_with_ft.py) file.

# %%
from answers_with_ft import answer_question
answer_question(olympics_search_fileid, ft_qa, "Which country won the Women's football tournament at the 2020 Olympic games?")
# Out:
# " Canada won the Women's football tournament at the 2020 Olympic games"
